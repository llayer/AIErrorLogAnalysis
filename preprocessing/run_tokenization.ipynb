# %%
import tokens

# %%
data = tokens.load_data()

# %%
data.head()
# Out:
#                                            task_name  error           site  \
# 0  /fabozzi_Run2016F-v1-MuonEG-07Aug17_8029_17083...     85   T2_US_Purdue
# 1  /fabozzi_Run2016F-v1-MuonEG-07Aug17_8029_17083...     85   T2_US_Purdue
# 2  /fabozzi_Run2016F-v1-MuonEG-07Aug17_8029_17083...     85   T2_US_Purdue
# 3  /fabozzi_Run2016F-v1-MuonEG-07Aug17_8029_17083...     85   T2_US_Purdue
# 4  /fabozzi_Run2016G-v1-DoubleMuonLowMass-07Aug17...     85  T2_US_Florida
#
#    exit_codes                                          error_msg  \
# 0       99999     Could not find report file for step stageOut1!
# 1          85    Adding last 25 lines of CMSSW stdout:     3 ...
# 2        8021  An exception of category 'FileReadError' occur...
# 3       99999  Adding extra error in order to hold error repo...
# 4       99999     Could not find report file for step stageOut1!
#
#                 error_type  steps_counter      names  peakvaluerss  \
# ...

# %%
reload(tokens)
tokens.tokenize_chunks(data, 'tokens', 10)
# Out:
# Processing chunk  0 / 10
# tokens.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   frame['error_msg'] = frame['error_msg'].apply(t.tokenize)
# /cvmfs/sft-nightlies.cern.ch/lcg/views/dev3/Tue/x86_64-centos7-gcc8-opt/lib/python2.7/site-packages/pandas/core/generic.py:2377: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->['task_name', 'site', 'error_msg', 'error_type', 'names', '_c0']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
# Processing chunk  1 / 10
# Processing chunk  2 / 10
# Processing chunk  3 / 10
# Processing chunk  4 / 10
# Processing chunk  5 / 10
# Processing chunk  6 / 10
# ...
